# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cars_data=pd.read_csv(r"C:\computer science\nptel\Toyota.csv",index_col=0,na_values=["??","????"])

# %%
cars_data
# Out:
#       Price   Age       KM FuelType     HP  MetColor  Automatic    CC  Doors  \
# 0     13500  23.0  46986.0   Diesel   90.0       1.0          0  2000  three
# 1     13750  23.0  72937.0   Diesel   90.0       1.0          0  2000      3
# 2     13950  24.0  41711.0   Diesel   90.0       NaN          0  2000      3
# 3     14950  26.0  48000.0   Diesel   90.0       0.0          0  2000      3
# 4     13750  30.0  38500.0   Diesel   90.0       0.0          0  2000      3
# ...     ...   ...      ...      ...    ...       ...        ...   ...    ...
# 1431   7500   NaN  20544.0   Petrol   86.0       1.0          0  1300      3
# 1432  10845  72.0      NaN   Petrol   86.0       0.0          0  1300      3
# 1433   8500   NaN  17016.0   Petrol   86.0       0.0          0  1300      3
# 1434   7250  70.0      NaN      NaN   86.0       1.0          0  1300      3
# 1435   6950  76.0      1.0   Petrol  110.0       0.0          0  1600      5
#
#       Weight
# 0       1165
# 1       1165
# 2       1165
# 3       1165
# 4       1170
# ...      ...
# 1431    1025
# 1432    1015
# 1433    1015
# 1434    1015
# 1435    1114
#
# [1436 rows x 10 columns]

# %%
#remove missing values
cars_data.dropna(axis=0,inplace=True)

# %%
cars_data.shape
# Out:
# (1096, 10)

# %%
#scatter plot in sea born

# %%
#price vs age

# %%
sns.set(style="darkgrid")
sns.regplot(x=cars_data['Age'],y=cars_data['Price'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Price'>

# %%
#scatter plot without regression fit line
sns.regplot(x=cars_data['Age'],y=cars_data['Price'],fit_reg=False)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Price'>

# %%
#change markers
sns.regplot(x=cars_data['Age'],y=cars_data['Price'],marker="*",fit_reg=False)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Price'>

# %%
#scatter plot of price vs age by fueltype----hue is used
sns.lmplot(x='Age',y='Price',data=cars_data,fit_reg=False,hue='FuelType',legend=True,palette="Set1")

# %%
#histogram---input should be continuous variable

# %%
sns.displot(cars_data['Age'])

# %%
sns.displot(cars_data['Age'],kde=False)

# %%
sns.displot(cars_data['Age'],kde=False,bins=5)

# %%
#bar chart
sns.countplot(x="FuelType",data=cars_data)
# Out:
# <AxesSubplot:xlabel='FuelType', ylabel='count'>

# %%
#grouped bar plot of fueltype and automatic

# %%
sns.countplot(x="FuelType",data=cars_data,hue="Automatic")
# Out:
# <AxesSubplot:xlabel='FuelType', ylabel='count'>

# %%
#box and whiskers plot-numerical variable

# %%
sns.boxplot(y=cars_data["Price"])
# Out:
# <AxesSubplot:ylabel='Price'>

# %%
#box and whiskers plot for numerical vs categorical variable

# %%
sns.boxplot(x=cars_data['FuelType'],y=cars_data["Price"])
# Out:
# <AxesSubplot:xlabel='FuelType', ylabel='Price'>

# %%
#grouped box and whisker plot of price vs fuel type ans automatic

# %%
sns.boxplot(x=cars_data['FuelType'],y=cars_data["Price"],hue='Automatic',data=cars_data)
# Out:
# <AxesSubplot:xlabel='FuelType', ylabel='Price'>

# %%
#box whisker plot and histogram
f,(ax_box,ax_hist)=plt.subplots(2,gridspec_kw={"height_ratios":(.15,.85)})

# %%
#now add create two plots

# %%
sns.boxplot(cars_data["Price"],ax=ax_box)
sns.displot(cars_data["Price"],ax=ax_hist,kde=False)
# Out:
# C:\Users\91945\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2142: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)

# %%
#pairwise plot

# %%
#it is used to plot pairwise relationship in a dataset
#create scatterplots for joints relationships and histogram for univariate distribution

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.pairplot(cars_data,Kind="scatter",hue="FuelType")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[52], line 3
#       1 import matplotlib.pyplot as plt
#       2 import seaborn as sns
# ----> 3 sns.pairplot(cars_data,Kind="scatter",hue="FuelType")
#       4 plt.show()
#
# TypeError: pairplot() got an unexpected keyword argument 'Kind'
